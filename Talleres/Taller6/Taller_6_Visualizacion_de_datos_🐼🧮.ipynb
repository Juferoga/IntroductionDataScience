# %% [markdown]
# # 👻  **Taller 6 - visualizar datos 🐼 🧮**
#
# <img src="https://www.udistrital.edu.co/themes/custom/versh/images/default/preloader.png" align="left" width="192px" height="192px"/>
# <img align="left" width="0" height="192px" hspace="10"/>
#
# > Juan Felipe Rodríguez Galindo  - **COD. 20181020158**
# <br></br>
# [![Juan Felipe Rodriguez Galindo](https://img.shields.io/badge/Juferoga-github-br?style=flat-square)](https://gitlab.com/Juferoga)
# [![License](https://img.shields.io/badge/License-GPL_V.3-blue?style=flat-square)](https://www.gnu.org/licenses/gpl-3.0.html)
#
#
# Introducción a la Ciencia de Datos
#
# Desarrrollo del taller propuesto en la clase de introducción a la ciencia de datos.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Taller
#
# ```
# Generar un reporte gráfico de un Data set (libre elección) que como mínimo incluya los siguientes tipos de gráficas:
#   plot,
#   bar,
#   area,
#   hist,
#   box,
#   pie,
#   table,
#   scatter,
#   scatter matrix,
#   radViz,
#   colormaps (aplicar a cualquier tipo de gráfica).
# ```

# %% [markdown]
# ## **Desarrollo**

# %%
# 📚 Librerias necesarias ...

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Pandas 🐼 Numpy 🇳 and MatplotLib 🧮 imported succesfully!!")
# Out:
# Pandas 🐼 Numpy 🇳 and MatplotLib 🧮 imported succesfully!!

# %%
# Funciones Utiles

# %%
# Creando el DataFrame 🛥️
 
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Datasets/train.csv')
#print (df)
print()
print("DataFrame imported - Titanic csv 🛥️")
print()
df
# Out:
# DataFrame imported - Titanic csv 🛥️
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
# plot

df['Survived'].cumsum().plot()

# %%
# bar

df.Embarked.value_counts().plot(kind = 'bar', color='y')

# %%
# area
df['Embarked'].value_counts().plot.area(stacked=False,colormap='hot')
df.plot.area(stacked=False,colormap='plasma')

# %%
# hist
#df.hist()#General
df['Age'].hist(bins=10)

# %%
# box
df['SibSp'].plot.box()

# %%
# pie
df['Pclass'].value_counts().plot.pie()

# %%
# table
df['Pclass'].value_counts().plot.pie(table=True,colormap='prism')
#fig, ax = plt.subplots(1,1)
#fd = pd.DataFrame(np.random.randint(1,10),columns=['a','b','c'])
#tb = pd.DataFrame(np.random.rand(18,3),columns=['a','b','c'])
#ax.get_xaxis().set_visible(False)
#fd.plot(table=tb, ax=ax)
#df.plot.table(row='Pclass',columns='Survived')

# %%
# scatter
df.plot.scatter(x='Age',y='PassengerId')

# %%
# scatter matrix
# df.plot.scatter(x='Age',y='PassengerId')
# df1 = pd.DataFrame(np.random.rand(1000, 4), columns=['a', 'b', 'c', 'd'])
df.plot.scatter(x='Age',y='Pclass')

# %%
# radViz

hdf = pd.DataFrame({ 'Precio'  : [1,2,3,5,3,4,3,2,3,2,3,2],
      'Precio1' : [4,3,4,4,3,2,1,3,4,2,2,2],
      'Precio2' : [1,2,3,3,4,3,2,3,2,2,3,1],
      'categoria' : ['Acetato', 'Lapiz', 'Esfero', 'Cuaderno','Lapiz','Lapiz', 'Esfero', 'Cuaderno', 'Lapiz', 'Esfero', 'Acetato', 'Acetato',]
      })
rad_viz = pd.plotting.radviz(hdf, 'categoria')

# %%
# colormaps
  #df.Embarked.value_counts().plot.bar(colormap='gist_rainbow')
df['Pclass'].value_counts().plot.pie(colormap='inferno')

# %% [markdown]
# <hr>

# %% [markdown]
#                              Fin Taller - visualizar datos pandas🐼 y matplotlib 🧮
#
# > Juan Felipe Rodríguez Galindo  - **COD. 20181020158**

# %%
# Pruebas ...
fig = plt.figure(figsize=(20,10))

for t_class in [1,2,3]:
    df.Age[df.Pclass == t_class].plot(kind='kde')
    
plt.legend(("1ra. Clase", "2da. Clase", "3ra.Clase"))  
plt.show()
